# %%
import redis

redis_client = redis.Redis.from_url('redis://default:redispw@localhost:32768')

redis_client.ping()  # Check if the connection is successful
redis_client.keys('*')
# Out:
# [b'181524833195130881',
#  b'319921436519038977',
#  b'229520869070733312',
#  b'716744693345550336',
#  b'186117853999661056']

# %%
redis_client.get()  # Ensure the connection is established
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 redis_client.connect()  # Ensure the connection is established
#
# AttributeError: 'Redis' object has no attribute 'connect'
